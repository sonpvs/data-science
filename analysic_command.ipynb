# %% [markdown]
# ## Data science in python
# Nhằm tập hợp những câu lệnh, hàm hữu ích phục vụ phân tích dữ liệu. Đây là những mẫu câu lệnh cần tham khảo.

# %% [markdown]
# ### 1. Đọc dữ liệu
#
# ![image.png](attachment:image.png)

# %%
import pandas as pd

# %%
df = pd.read_csv('pokemon_data.csv')

# print(df.head(5))

# df_xlsx = pd.read_excel('pokemon_data.xlsx')
# print(df_xlsx.head(3))

# df = pd.read_csv('pokemon_data.txt', delimiter='\t')

# %%
print(df.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# ### Tham khảo thêm
#
# https://github.com/codebasics/py/blob/master/pandas/4_read_write_to_excel/read_write_csv_excel.ipynb

# %% [markdown]
# ### Python Pandas Tutorial 1. What is Pandas python? Introduction and Installation
#
# https://www.youtube.com/watch?v=CmorAWRsCAw&list=PLeo1K3hjS3uuASpe-1LjfG5f14Bnozjwy

# %% [markdown]
# ### Xử lý dữ liệu lỗi
#
# https://github.com/codebasics/py/blob/master/pandas/5_handling_missing_data_fillna_dropna_interpolate/handling_missing_data_fillna_dropna_interpolate.ipynb
#
# Có thể tham khảo thêm hàm replace
#
# https://github.com/codebasics/py/blob/master/pandas/6_handling_missing_data_replace/handling_missing_data_replace.ipynb

# %% [markdown]
# ### Phân nhóm dữ liệu qua hàm Grouyby
#
# https://github.com/codebasics/py/blob/master/pandas/7_group_by/pandas_group_by.ipynb

# %% [markdown]
# ### Ghép dữ liệu qua hàm Concat
#
# https://github.com/codebasics/py/blob/master/pandas/8_concat/pandas_concat.ipynb

# %% [markdown]
# ### Trộn dữ liệu qua hàm Merge
#
# https://github.com/codebasics/py/blob/master/pandas/9_merge/pandas_merge.ipynb

# %% [markdown]
# ### Nhóm thành bảng tổng hợp qua Pivot table
#
# https://github.com/codebasics/py/blob/master/pandas/10_pivot/pandas_pivot.ipynb

# %% [markdown]
# ### Định hình lại khung dữ liệu bằng cách sử dụng Melt
#
# https://github.com/codebasics/py/blob/master/pandas/11_melt/pandas_melt_tutorial.ipynb

# %% [markdown]
# ### Python Pandas Tutorial 12. Stack Unstack
#
# https://github.com/codebasics/py/blob/master/pandas/12_stack/12_pandas_stack.ipynb

# %% [markdown]
# ### Python Pandas Tutorial 13. Crosstab
#
# https://github.com/codebasics/py/blob/master/pandas/13_crosstab/pandas_crosstab.ipynb

# %% [markdown]
# ### Python Pandas Tutorial 14: Read Write Data From Database (read_sql, to_sql)
#
# https://github.com/codebasics/py/blob/master/pandas/21_sql/pandas_sql.ipynb

# %% [markdown]
# ### Pandas Time Series Analysis Part 1: DatetimeIndex and Resample
#
# https://github.com/codebasics/py/blob/master/pandas/14_ts_datetimeindex/pandas_ts_datetime_index.ipynb

# %% [markdown]
# ### Pandas Time Series Analysis Part 2: date_range
#
# https://github.com/codebasics/py/tree/master/pandas/15_ts_date_range

# %% [markdown]
# ### Pandas Time Series Analysis 3: Holidays
#
# https://github.com/codebasics/py/tree/master/pandas/16_ts_holidays

# %% [markdown]
# ### Pandas Time Series Analysis 4: to_datetime
#
# https://github.com/codebasics/py/blob/master/pandas/17_ts_to_date_time/pandas_ts_to_date_time.ipynb

# %% [markdown]
# ### Pandas Time Series Analysis 5: Period and PeriodIndex
#
# https://github.com/codebasics/py/blob/master/pandas/18_ts_period/pandas_ts_period.ipynb

# %% [markdown]
# ### Pandas Time Series Analysis 6: Timezone Handling
#
# https://github.com/codebasics/py/blob/master/pandas/19_ts_timezone/pandas_timezone_handling.ipynb

# %% [markdown]
# ### Pandas Time Series Analysis 6: Shifting and Lagging
#
# https://github.com/codebasics/py/blob/master/pandas/20_shift_lag/pandas_shift_lag.ipynb

# %% [markdown]
# ### Python Pandas Tutorial 15. Handle Large Datasets In Pandas | Memory Optimization Tips For Pandas
#
# https://pythonspeed.com/articles/pandas-load-less-data/
